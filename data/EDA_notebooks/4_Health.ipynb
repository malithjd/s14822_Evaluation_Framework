# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#importing health_insurance dataset
df=pd.read_csv("G:\\Internship\\Surge\\For Evaluation\\Project\\data\\datatables\\4_Health.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#reading dataset
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#entire dataset in a nutshell
df.describe().T
# Out:
#            count          mean           std        min         25%       50%  \
# age       1338.0     39.207025     14.049960    18.0000    27.00000    39.000
# bmi       1338.0     30.663397      6.098187    15.9600    26.29625    30.400
# children  1338.0      1.094918      1.205493     0.0000     0.00000     1.000
# charges   1338.0  13270.422265  12110.011237  1121.8739  4740.28715  9382.033
#
#                    75%          max
# age          51.000000     64.00000
# bmi          34.693750     53.13000
# children      2.000000      5.00000
# charges   16639.912515  63770.42801

# %%
#it returns the no.of rows and columns (1338 rows, 7 columns)
df.shape
# Out:
# (1338, 7)

# %%
#checking for any null values
df.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#checking unique values for each column
df.nunique()
# Out:
# age           47
# sex            2
# bmi          548
# children       6
# smoker         2
# region         4
# charges     1337
# dtype: int64

# %%
#accessing the columns name
col=df.columns
col
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # # **CHARTS**

# %%
#library import
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## **1. Distribution of Column Values**

# %%
# fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 8))
# sns.histplot(df,x='sex',shrink=0.5, edgecolor='black',ax=axs[0][0],linewidth=0.5)
# axs[0, 0].set_title('Distribution of Sex')

# sns.histplot(df,x='children',shrink=0.8,discrete=True, edgecolor='black',linewidth=0.5,ax=axs[0][1])
# axs[0, 0].set_title('Distribution of Children')

# sns.histplot(df,x='smoker',shrink=0.5, edgecolor='black',ax=axs[1][0],linewidth=0.5)
# axs[0, 0].set_title('Distribution of Smoker')

# sns.histplot(df,x='region',shrink=0.5, edgecolor='black',ax=axs[1][1],linewidth=0.5)
# axs[0, 0].set_title('Distribution of Region')


# Orginal code above!
# It was replaced by below 4 cells to generate each visual one by one

# %%
# Assuming 'df' is your pandas DataFrame
plt.figure(figsize=(5, 4))
sns.histplot(df, x='sex', shrink=0.5, edgecolor='black', linewidth=0.5)
plt.title('Distribution of Sex')
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.histplot(df, x='children', shrink=0.8, discrete=True, edgecolor='black', linewidth=0.5)
plt.title('Distribution of Children')
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.histplot(df, x='smoker', shrink=0.5, edgecolor='black', linewidth=0.5)
plt.title('Distribution of Smoker')
plt.show()

# %%
plt.figure(figsize=(5, 4))
sns.histplot(df, x='region', shrink=0.5, edgecolor='black', linewidth=0.5)
plt.title('Distribution of Region')
plt.show()

# %% [markdown]
# ## **2. BMI Analysis**
# There are 4 categories of BMI each of them having a particular range as;
#
# **BMI Range      :	Weight Status**
# Below 18.5       :	Underweight
# 18.5 – 24.9      :	Healthy Weight
# 25.0 – 29.9      :	Overweight
# 30.0 and Above   :	Obesity

# %%
df["category"]=pd.cut(data['bmi'],[0,18.0,24.9,29.9,100],labels=["Underweight","Healthy Weight","Overweight","Obesity"])
a=sns.histplot(df,x='category',shrink=0.5, edgecolor='black')
a.set_title('Distribution of BMI by category')
# Out:
# Text(0.5, 1.0, 'Distribution of BMI by category')

# %%
bmi_result=data.groupby(["category"]).agg({"charges":["mean"]})
sns.barplot(x="category", y="charges", data=df, edgecolor='black',linewidth=0.5,errorbar=None)
plt.title("Mean Charges vs Category")
# Out:
# Text(0.5, 1.0, 'Mean Charges vs Category')

# %% [markdown]
# ## **3. Region vs Charges Analysis**

# %%
region_result=data.groupby(["region"]).agg({"charges":['mean']})
sns.barplot(data,x="region", y="charges", edgecolor='black',linewidth=0.5,errorbar=None)
plt.title("Average Charges vs Region")
# Out:
# Text(0.5, 1.0, 'Average Charges vs Region')

# %%
charges_age_sex=data.groupby(["region","sex"]).agg({"sex":['count'],"age":['mean'],"charges":['mean']})
charges_age_sex
# Out:
#                    sex        age       charges
#                  count       mean          mean
# region    sex
# northeast female   161  39.639752  12953.203151
#           male     163  38.901840  13854.005374
# northwest female   164  39.591463  12479.870397
#           male     161  38.795031  12354.119575
# southeast female   175  39.108571  13499.669243
#           male     189  38.783069  15879.617173
# southwest female   162  39.703704  11274.411264
#           male     163  39.208589  13412.883576

# %% [markdown]
# ## **4. Charges vs (Smoker & Sex) Analysis**

# %%
sex_smoke=data.groupby(["smoker","sex"]).agg({"charges":['mean']})
sex_smoke
# Out:
#                     charges
#                        mean
# smoker sex
# no     female   8762.297300
#        male     8087.204731
# yes    female  30678.996276
#        male    33042.005975

# %%
sns.barplot(data,x="smoker", y="charges",hue='sex',width=0.5, edgecolor='black',linewidth=0.5,errorbar=None)
plt.title("Average Charges vs Smoker")
# Out:
# Text(0.5, 1.0, 'Average Charges vs Smoker')

# %% [markdown]
# ## **5. Age vs Charges Analysis**

# %%
age_charges=df.groupby(["age"]).agg({"charges":['mean']})
plt.figure(figsize=(15, 5)) 
sns.barplot(df,x="age", y="charges", edgecolor='black',linewidth=0.5,errorbar=None)
plt.title("Average Charges vs Smoker")
# Out:
# Text(0.5, 1.0, 'Average Charges vs Smoker')
